# %% [markdown]
# # SNP Table Workflow
#
# This notebook contains the workflow completed to replicate Table 2. Minor nucleotide variant identified from WHUO1 and WHUO2 genomes

# %% [markdown]
# ### Workflow Description
# __indexing reference__
# * purpose: prepare the reference genome for read alignment using BWA
# * the reference genome (`ref`) is indexed by bwa
#
# __read alignment (BWA)__
# * purpose: align cleaned sequencing reads from each patient to the reference genome
# * each merged fastq file (paired-end reads concatenated) is aligned using bwa mem
# * the output is saved as a .sam file (sequence alignment/map format)
#
# __converting sam to bam & sorting (SAMtools)__
# * purpose: convert and organize alignment data to be efficient for variant calling
# * .sam files are converted to .bam (binary format)
# * BAM files are sorted and indexed for random access by variant callers
#
# __variant calling (bcftools)__
# * purpose: identify genomic differences (SNPs, indels) between each sample and the reference genome
# * `bctools mpileuup` reads alignment data and calculates genotype likelihoods
# * `bcftools call` identifies variants based on likelihoods and outputs a .vcf file
#
# __parsing vcf to a table__
# * purpose: transform raw variant data into a readable and filterable table for downstream analysis
# * each vcf file is parsed using vcfpy
# * for each variant, position, reference/alternate allele, coverage, quality, and type are extracted
# * data is stored in pandas df
#     * strain: patient identifier (WHU01/WHU02)
#     * start position: ref genome position of the variant
#     * end position: end position (useful for indels)
#     * length: length of ref allele
#     * change: description of mutation
#     * coverage: read depth at the variant site
#     * polymorphism type: SNP or indel
#     * variant frequency: NA
#     * quality: variant confidence score: NA

# %%
import subprocess
import os

# !pwd
# Out:
# /Users/lilliang/Documents/Spring_2025/EEOB5460/EEOB5460_final_project2025

# %%
# function to print all rows of a df (useful when troubleshooting data clean-up steps)
def print_full(x):
    import pandas as pd
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print(x)

# %%
# files
ref = "working_files/viral_ref_genome_output.fasta"
samples = {
    "WHU01": "working_files/wuhan1_merged.fastq",
    "WHU02": "working_files/wuhan2_merged.fastq"
}

# %%
# index reference (only once)
subprocess.run(["bwa", "index", ref])
# Out:
# [bwa_index] Pack FASTA... 3.24 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=1103023696, availableWord=89612688
# [BWTIncConstructFromPacked] 10 iterations done. 100000000 characters processed.
# [BWTIncConstructFromPacked] 20 iterations done. 200000000 characters processed.
# [BWTIncConstructFromPacked] 30 iterations done. 300000000 characters processed.
# [BWTIncConstructFromPacked] 40 iterations done. 400000000 characters processed.
# [BWTIncConstructFromPacked] 50 iterations done. 496873216 characters processed.
# [BWTIncConstructFromPacked] 60 iterations done. 583320176 characters processed.
# [BWTIncConstructFromPacked] 70 iterations done. 660150432 characters processed.
# [BWTIncConstructFromPacked] 80 iterations done. 728433360 characters processed.
# [BWTIncConstructFromPacked] 90 iterations done. 789119392 characters processed.
# [BWTIncConstructFromPacked] 100 iterations done. 843053280 characters processed.
# [BWTIncConstructFromPacked] 110 iterations done. 890985840 characters processed.
# [BWTIncConstructFromPacked] 120 iterations done. 933584400 characters processed.
# [BWTIncConstructFromPacked] 130 iterations done. 971442080 characters processed.
# [BWTIncConstructFromPacked] 140 iterations done. 1005086048 characters processed.
# [BWTIncConstructFromPacked] 150 iterations done. 1034984864 characters processed.
# [BWTIncConstructFromPacked] 160 iterations done. 1061554992 characters processed.
# [BWTIncConstructFromPacked] 170 iterations done. 1085166560 characters processed.
# [bwt_gen] Finished constructing BWT in 179 iterations.
# [bwa_index] 294.75 seconds elapse.
# 2.32 secex] Update BWT...
# 1.89 secex] Pack forward-only FASTA...
# 108.18 sec] Construct SA from BWT and Occ...
# [main] Version: 0.7.19-r1273
# [main] CMD: bwa index working_files/viral_ref_genome_output.fasta
# [main] Real time: 413.363 sec; CPU: 410.373 sec
# CompletedProcess(args=['bwa', 'index', 'working_files/viral_ref_genome_output.fasta'], returncode=0)

# %%
# align reads to reference, convert to sorted BAM and index 
for name, fastq in samples.items():
    sam = os.path.join("working_files", f"{name}.sam")
    bam = os.path.join("working_files", f"{name}.bam")
    sorted_bam = os.path.join("working_files", f"{name}_sorted.bam")

    subprocess.run(["bwa", "mem", ref, fastq], stdout=open(sam, "w"), check = True)
    subprocess.run(["samtools", "view", "-bS", sam, "-o", bam], check = True)
    subprocess.run(["samtools", "sort", bam, "-o", sorted_bam], check = True)
    subprocess.run(["samtools", "index", sorted_bam], check = True)
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 71864 sequences (10000209 bp)...
# [M::process] read 71648 sequences (10000178 bp)...
# [M::mem_process_seqs] Processed 71864 reads in 6.937 CPU sec, 6.921 real sec
# [M::process] read 71950 sequences (10000031 bp)...
# [M::mem_process_seqs] Processed 71648 reads in 5.875 CPU sec, 5.774 real sec
# [M::process] read 71656 sequences (10000220 bp)...
# [M::mem_process_seqs] Processed 71950 reads in 5.695 CPU sec, 5.592 real sec
# [M::process] read 71774 sequences (10000249 bp)...
# [M::mem_process_seqs] Processed 71656 reads in 5.490 CPU sec, 5.447 real sec
# [M::process] read 71960 sequences (10000285 bp)...
# [M::mem_process_seqs] Processed 71774 reads in 6.257 CPU sec, 6.150 real sec
# [M::process] read 71732 sequences (10000281 bp)...
# [M::mem_process_seqs] Processed 71960 reads in 6.888 CPU sec, 6.781 real sec
# [M::process] read 72228 sequences (10000021 bp)...
# [M::mem_process_seqs] Processed 71732 reads in 7.412 CPU sec, 7.306 real sec
# [M::process] read 71750 sequences (10000248 bp)...
# [M::mem_process_seqs] Processed 72228 reads in 7.133 CPU sec, 7.020 real sec
# [M::process] read 71306 sequences (10000120 bp)...
# [M::mem_process_seqs] Processed 71750 reads in 5.748 CPU sec, 5.635 real sec
# [M::process] read 72086 sequences (10000128 bp)...
# [M::mem_process_seqs] Processed 71306 reads in 5.388 CPU sec, 5.277 real sec
# [M::process] read 71674 sequences (10000236 bp)...
# [M::mem_process_seqs] Processed 72086 reads in 5.575 CPU sec, 5.467 real sec
# [M::process] read 71488 sequences (10000112 bp)...
# [M::mem_process_seqs] Processed 71674 reads in 5.588 CPU sec, 5.484 real sec
# [M::process] read 71998 sequences (10000138 bp)...
# [M::mem_process_seqs] Processed 71488 reads in 5.500 CPU sec, 5.389 real sec
# [M::process] read 71362 sequences (10000118 bp)...
# [M::mem_process_seqs] Processed 71998 reads in 5.603 CPU sec, 5.495 real sec
# [M::process] read 72280 sequences (10000297 bp)...
# [M::mem_process_seqs] Processed 71362 reads in 5.392 CPU sec, 5.276 real sec
# [M::process] read 26544 sequences (3708511 bp)...
# [M::mem_process_seqs] Processed 72280 reads in 5.687 CPU sec, 5.596 real sec
# [M::mem_process_seqs] Processed 26544 reads in 2.107 CPU sec, 2.028 real sec
# [main] Version: 0.7.19-r1273
# [main] CMD: bwa mem working_files/viral_ref_genome_output.fasta working_files/wuhan1_merged.fastq
# [main] Real time: 97.909 sec; CPU: 99.119 sec
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 71690 sequences (10000244 bp)...
# [M::process] read 72096 sequences (10000009 bp)...
# [M::mem_process_seqs] Processed 71690 reads in 5.541 CPU sec, 5.496 real sec
# [M::process] read 71688 sequences (10000066 bp)...
# [M::mem_process_seqs] Processed 72096 reads in 5.733 CPU sec, 5.628 real sec
# [M::process] read 71990 sequences (10000257 bp)...
# [M::mem_process_seqs] Processed 71688 reads in 5.881 CPU sec, 5.787 real sec
# [M::process] read 71812 sequences (10000085 bp)...
# [M::mem_process_seqs] Processed 71990 reads in 7.416 CPU sec, 7.414 real sec
# [M::process] read 72148 sequences (10000126 bp)...
# [M::mem_process_seqs] Processed 71812 reads in 8.008 CPU sec, 7.977 real sec
# [M::process] read 71524 sequences (10000216 bp)...
# [M::mem_process_seqs] Processed 72148 reads in 6.752 CPU sec, 6.701 real sec
# [M::process] read 71998 sequences (10000205 bp)...
# [M::mem_process_seqs] Processed 71524 reads in 5.474 CPU sec, 5.366 real sec
# [M::process] read 71724 sequences (10000118 bp)...
# [M::mem_process_seqs] Processed 71998 reads in 5.684 CPU sec, 5.576 real sec
# [M::process] read 71834 sequences (10000293 bp)...
# [M::mem_process_seqs] Processed 71724 reads in 5.891 CPU sec, 5.829 real sec
# [M::process] read 72240 sequences (10000287 bp)...
# [M::mem_process_seqs] Processed 71834 reads in 5.852 CPU sec, 5.788 real sec
# [M::process] read 8762 sequences (1229468 bp)...
# [M::mem_process_seqs] Processed 72240 reads in 5.509 CPU sec, 5.436 real sec
# [M::mem_process_seqs] Processed 8762 reads in 0.753 CPU sec, 0.674 real sec
# [main] Version: 0.7.19-r1273
# [main] CMD: bwa mem working_files/viral_ref_genome_output.fasta working_files/wuhan2_merged.fastq
# [main] Real time: 68.523 sec; CPU: 69.212 sec

# %%
# variant calling: create VCFs
for name in samples.keys():
    sorted_bam = os.path.join("working_files", f"{name}_sorted.bam")
    raw_bcf = os.path.join("working_files", f"{name}_raw.bcf")
    vcf_file = os.path.join("working_files", f"{name}.vcf")

    with open(raw_bcf, "wb") as out_bcf:
        subprocess.run(["bcftools", "mpileup", "-f", ref, sorted_bam, "-Ou"], stdout=out_bcf)
    subprocess.run(["bcftools", "call", "-mv", "-Ov", "-o", vcf_file, raw_bcf])
# Out:
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Note: none of --samples-file, --ploidy or --ploidy-file given, assuming all sites are diploid
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# Note: none of --samples-file, --ploidy or --ploidy-file given, assuming all sites are diploid

# %%
import pandas as pd
import vcfpy as vcf 

def vcf_to_dataframe(vcf_file, strain):
    vcf_reader = vcf.Reader(open(vcf_file, 'r'))
    rows = []

    for record in vcf_reader:
        # safely extract ALT allele(s)
        alt_alleles = record.ALT
        try:
            alt = str(alt_alleles[0]) if alt_alleles else None
        except Exception:
            alt = None

        # determine length safely
        ref_len = len(record.REF) if record.REF else 0
        end_pos = record.POS + ref_len - 1 if record.POS and ref_len else record.POS

        # handle AF (allele frequency) values
        af_raw = record.INFO.get("AF", None)
        if isinstance(af_raw, list) and af_raw:
            af_percent = af_raw[0] * 100
        elif isinstance(af_raw, float):
            af_percent = af_raw * 100
        else:
            af_percent = None

        # determine polymorphism type
        polymorphism_type = "SNP" if ref_len == 1 and alt and len(str(alt)) == 1 else "Indel"

        rows.append({
            "Strain": strain,
            "Start Position": record.POS,
            "End Position": end_pos,
            "Length": ref_len,
            "Change": f"{record.REF} → {alt}" if alt else None,
            "Coverage": record.INFO.get("DP", None),
            "Polymorphism Type": polymorphism_type,
            "Variant Frequency (%)": af_percent,
            "Quality": record.QUAL
        })

    return pd.DataFrame(rows)

# %%
df1 = vcf_to_dataframe("working_files/WHU01.vcf", "WHU01")
df2 = vcf_to_dataframe("working_files/WHU02.vcf", "WHU02")

variants_df = pd.concat([df1, df2]).sort_values(by=["Strain", "Start Position"])
variants_df.reset_index(drop=True, inplace=True)

# %%
print_full(variants_df)
# Out:
#     Strain  Start Position  End Position  Length  \
# 0    WHU01               2             2       1
# 1    WHU01              23            23       1
# 2    WHU01              34            34       1
# 3    WHU01              40            40       1
# 4    WHU01              51            51       1
# 5    WHU01              59            59       1
# 6    WHU01              66            66       1
# 7    WHU01              67            67       1
# 8    WHU01             103           103       1
# 9    WHU01             113           113       1
# 10   WHU01             117           117       1
# 11   WHU01             118           118       1
# 12   WHU01             127           127       1
# 13   WHU01             134           134       1
# 14   WHU01             137           137       1
# 15   WHU01             139           139       1
# 16   WHU01             169           169       1
# 17   WHU01             178           178       1
# 18   WHU01             181           181       1
# 19   WHU01             182           182       1
# 20   WHU01             248           248       1
# 21   WHU01             281           281       1
# 22   WHU01             289           289       1
# 23   WHU01             309           309       1
# 24   WHU01             342           342       1
# 25   WHU01             362           362       1
# 26   WHU01             558           558       1
# 27   WHU01             574           574       1
# 28   WHU01             587           587       1
# 29   WHU01             608           608       1
# 30   WHU01             665           665       1
# 31   WHU01             671           671       1
# 32   WHU01             707           707       1
# 33   WHU01             833           833       1
# 34   WHU01             872           872       1
# 35   WHU01             874           874       1
# 36   WHU01             876           876       1
# 37   WHU01            1152          1152       1
# 38   WHU01            1231          1231       1
# 39   WHU01            1235          1235       1
# 40   WHU01            1317          1317       1
# 41   WHU01            1319          1319       1
# 9             T → Substitution(type_='SNV', value='C')         1
# 10            A → Substitution(type_='SNV', value='G')        27
# 11            T → Substitution(type_='SNV', value='A')        29
# 12            G → Substitution(type_='SNV', value='A')        58
# 13            G → Substitution(type_='SNV', value='T')        61
# 14            C → Substitution(type_='SNV', value='T')        61
# 15            A → Substitution(type_='SNV', value='T')        63
# 16            A → Substitution(type_='SNV', value='C')        19
# 17            T → Substitution(type_='SNV', value='G')        20
# 18            A → Substitution(type_='SNV', value='G')         4
# 19            T → Substitution(type_='SNV', value='C')        21
# 20            T → Substitution(type_='SNV', value='C')         5
# 21            A → Substitution(type_='SNV', value='G')         4
# 22            A → Substitution(type_='SNV', value='C')         4
# 23            A → Substitution(type_='SNV', value='T')         4
# 24            A → Substitution(type_='SNV', value='T')        42
# 25            T → Substitution(type_='SNV', value='A')        42
# 26            C → Substitution(type_='SNV', value='A')         3
# 27            G → Substitution(type_='SNV', value='A')         2
# 28            G → Substitution(type_='SNV', value='A')       251
# 29            T → Substitution(type_='SNV', value='C')         4
# 30            T → Substitution(type_='SNV', value='C')         4
# 31            T → Substitution(type_='SNV', value='C')         4
# 32            T → Substitution(type_='SNV', value='C')         7
# 33            G → Substitution(type_='SNV', value='A')       250
# 34            A → Substitution(type_='SNV', value='G')        18
# 35            G → Substitution(type_='SNV', value='A')        12
# 36            A → Substitution(type_='SNV', value='G')         6
# 37            A → Substitution(type_='SNV', value='C')         1
# 38            A → Substitution(type_='SNV', value='G')         7
# 39            T → Substitution(type_='SNV', value='C')         7
# 40            C → Substitution(type_='SNV', value='A')         1
# 41            C → Substitution(type_='SNV', value='T')         9
# 42            G → Substitution(type_='SNV', value='A')        11
# 43            A → Substitution(type_='SNV', value='G')        14
# 44            T → Substitution(type_='SNV', value='C')        12
# 45            T → Substitution(type_='SNV', value='C')        11
# 46            T → Substitution(type_='SNV', value='C')         7
# 47            C → Substitution(type_='SNV', value='G')         4
# 48            C → Substitution(type_='SNV', value='G')         8
# 49            T → Substitution(type_='SNV', value='C')        11
# 50            T → Substitution(type_='SNV', value='C')         7
# 51            A → Substitution(type_='SNV', value='C')         5
# 52            A → Substitution(type_='SNV', value='C')         6
# 53            T → Substitution(type_='SNV', value='C')         8
# 54            A → Substitution(type_='SNV', value='G')        10
# 55            G → Substitution(type_='SNV', value='A')         2
# 56            A → Substitution(type_='SNV', value='G')         2
# 57            C → Substitution(type_='SNV', value='A')         7
# 58            A → Substitution(type_='SNV', value='G')       251
# 59            C → Substitution(type_='SNV', value='T')       249
# 60            T → Substitution(type_='SNV', value='C')         4
# 61            C → Substitution(type_='SNV', value='T')         4
# 62            C → Substitution(type_='SNV', value='T')       252
# 63            T → Substitution(type_='SNV', value='C')         7
# 64            T → Substitution(type_='SNV', value='C')        10
# 65            C → Substitution(type_='SNV', value='T')         6
# 66            C → Substitution(type_='SNV', value='T')         5
# 67            A → Substitution(type_='SNV', value='C')         6
# 68            C → Substitution(type_='SNV', value='T')         3
# 69            C → Substitution(type_='SNV', value='T')         2
# 70            G → Substitution(type_='SNV', value='T')         8
# 71            T → Substitution(type_='SNV', value='C')        10
# 72            A → Substitution(type_='SNV', value='G')        11
# 73            T → Substitution(type_='SNV', value='C')        12
# 74            A → Substitution(type_='SNV', value='G')        14
# 75            C → Substitution(type_='SNV', value='A')        11
# 76            A → Substitution(type_='SNV', value='G')        14
# 77            T → Substitution(type_='SNV', value='A')        12
# 78            A → Substitution(type_='SNV', value='C')         1
# 79            G → Substitution(type_='SNV', value='A')        11
# 80            C → Substitution(type_='SNV', value='T')        10
# 81            T → Substitution(type_='SNV', value='G')        11
# 82            C → Substitution(type_='SNV', value='T')         5
# 83            A → Substitution(type_='SNV', value='G')         5
# 84            C → Substitution(type_='SNV', value='T')         5
# 85            G → Substitution(type_='SNV', value='A')         7
# 86            A → Substitution(type_='SNV', value='G')         6
# 87            C → Substitution(type_='SNV', value='T')         5
# 88            T → Substitution(type_='SNV', value='C')         5
# 89            G → Substitution(type_='SNV', value='A')         5
# 90            G → Substitution(type_='SNV', value='A')         6
# 91            T → Substitution(type_='SNV', value='C')         9
# 92            C → Substitution(type_='SNV', value='T')         7
# 93            C → Substitution(type_='SNV', value='T')         6
# 94            A → Substitution(type_='SNV', value='G')         6
# 95            G → Substitution(type_='SNV', value='A')         6
# 96            G → Substitution(type_='SNV', value='A')         4
# 97            A → Substitution(type_='SNV', value='T')         4
# 98            C → Substitution(type_='SNV', value='T')         4
# 99            C → Substitution(type_='SNV', value='T')         5
# 100           C → Substitution(type_='SNV', value='T')         8
# 101           C → Substitution(type_='SNV', value='T')         9
# 102           T → Substitution(type_='SNV', value='C')        18
# 103           A → Substitution(type_='SNV', value='G')        17
# 104           A → Substitution(type_='SNV', value='C')        18
# 105           C → Substitution(type_='SNV', value='A')        19
# 106           T → Substitution(type_='SNV', value='C')        18
# 107           T → Substitution(type_='SNV', value='C')        14
# 108           T → Substitution(type_='SNV', value='C')         9
# 109           T → Substitution(type_='SNV', value='C')         2
# 110           A → Substitution(type_='SNV', value='G')         8
# 111           T → Substitution(type_='SNV', value='C')         2
# 112           A → Substitution(type_='SNV', value='T')         6
# 113           T → Substitution(type_='SNV', value='G')         6
# 114           C → Substitution(type_='SNV', value='T')         4
# 115           C → Substitution(type_='SNV', value='G')         2
# 116           A → Substitution(type_='SNV', value='C')        24
# 117           A → Substitution(type_='SNV', value='G')        21
# 118           G → Substitution(type_='SNV', value='A')        21
# 119           A → Substitution(type_='SNV', value='G')        27
# 120           A → Substitution(type_='SNV', value='G')        42
# 121           C → Substitution(type_='SNV', value='T')        40
# 122           C → Substitution(type_='SNV', value='T')         2
# 123           T → Substitution(type_='SNV', value='C')         2
# 124           C → Substitution(type_='SNV', value='T')        42
# 125           T → Substitution(type_='SNV', value='C')         2
# 126           A → Substitution(type_='SNV', value='G')         2
# 127           G → Substitution(type_='SNV', value='A')        29
# 128           T → Substitution(type_='SNV', value='C')         2
# 129           A → Substitution(type_='SNV', value='T')         2
# 130           T → Substitution(type_='SNV', value='C')         2
# 131           C → Substitution(type_='SNV', value='T')         2
# 132           A → Substitution(type_='SNV', value='G')         7
# 133           G → Substitution(type_='SNV', value='A')         4
# 134           A → Substitution(type_='SNV', value='G')         4
# 135           G → Substitution(type_='SNV', value='A')         4
# 136           A → Substitution(type_='SNV', value='G')         3
# 137           G → Substitution(type_='SNV', value='C')         6
# 138           G → Substitution(type_='SNV', value='A')         7
# 139           C → Substitution(type_='SNV', value='T')         5
# 140  ATTTTT → Substitution(type_='INDEL', value='AT...         6
# 141           A → Substitution(type_='SNV', value='G')         7
# 142           T → Substitution(type_='SNV', value='C')         7
# 143           A → Substitution(type_='SNV', value='T')         3
# 144           T → Substitution(type_='SNV', value='C')         1
# 145           T → Substitution(type_='SNV', value='C')         3
# 146           C → Substitution(type_='SNV', value='T')         4
# 147           C → Substitution(type_='SNV', value='G')         5
# 148           T → Substitution(type_='SNV', value='C')         5
# 149           T → Substitution(type_='SNV', value='C')         3
# 150           T → Substitution(type_='SNV', value='A')         7
# 151           T → Substitution(type_='SNV', value='C')         5
# 152           G → Substitution(type_='SNV', value='A')         8
# 153           T → Substitution(type_='SNV', value='C')         3
# 154           A → Substitution(type_='SNV', value='G')         4
# 155           T → Substitution(type_='SNV', value='C')         6
# 156           T → Substitution(type_='SNV', value='G')         3
# 157           A → Substitution(type_='SNV', value='G')         7
# 158           C → Substitution(type_='SNV', value='T')         7
# 159      TCC → Substitution(type_='INDEL', value='TC')         7
# 160           C → Substitution(type_='SNV', value='T')         4
# 161           C → Substitution(type_='SNV', value='T')        10
# 162           G → Substitution(type_='SNV', value='C')        10
# 163           G → Substitution(type_='SNV', value='A')        10
# 164           C → Substitution(type_='SNV', value='A')        10
# 165           C → Substitution(type_='SNV', value='A')        10
# 166           T → Substitution(type_='SNV', value='C')         3
# 167           C → Substitution(type_='SNV', value='T')         4
# 168           G → Substitution(type_='SNV', value='T')         3
# 169           A → Substitution(type_='SNV', value='G')         6
# 170           T → Substitution(type_='SNV', value='C')         6
# 171           T → Substitution(type_='SNV', value='C')         6
# 172           T → Substitution(type_='SNV', value='G')         6
# 173           G → Substitution(type_='SNV', value='A')        84
# 174         ATT → Substitution(type_='DEL', value='A')        51
# 175           G → Substitution(type_='SNV', value='T')         1
# 176           C → Substitution(type_='SNV', value='T')         1
# 177           T → Substitution(type_='SNV', value='A')         1
# 178           T → Substitution(type_='SNV', value='A')         1
# 179           A → Substitution(type_='SNV', value='G')         1
# 180           G → Substitution(type_='SNV', value='A')         1
# 181           C → Substitution(type_='SNV', value='T')         1
# 182           T → Substitution(type_='SNV', value='A')         1
# 183           C → Substitution(type_='SNV', value='T')       226
# 184           C → Substitution(type_='SNV', value='G')       217
# 185           G → Substitution(type_='SNV', value='A')       217
# 186           A → Substitution(type_='SNV', value='G')        26
# 187           A → Substitution(type_='SNV', value='G')        23
# 188           T → Substitution(type_='SNV', value='G')         4
# 189           A → Substitution(type_='SNV', value='C')         5
# 190           T → Substitution(type_='SNV', value='A')         5
# 191           G → Substitution(type_='SNV', value='T')         2
# 192           T → Substitution(type_='SNV', value='G')         2
# 193           A → Substitution(type_='SNV', value='C')         2
# 194           C → Substitution(type_='SNV', value='T')         2
# 195           T → Substitution(type_='SNV', value='C')         2
# 196           T → Substitution(type_='SNV', value='C')         2
# 197           C → Substitution(type_='SNV', value='A')         2
# 198           A → Substitution(type_='SNV', value='T')         2
# 199           G → Substitution(type_='SNV', value='A')         1
# 200           A → Substitution(type_='SNV', value='C')         1
# 201           A → Substitution(type_='SNV', value='T')         2
# 202           G → Substitution(type_='SNV', value='A')         2
# 203           G → Substitution(type_='SNV', value='T')         2
# 204           C → Substitution(type_='SNV', value='G')         2
# 205  ACCCC → Substitution(type_='INDEL', value='ACCC')         2
# 206           A → Substitution(type_='SNV', value='T')        13
# 207           C → Substitution(type_='SNV', value='G')         3
# 208           T → Substitution(type_='SNV', value='C')         2
# 209           T → Substitution(type_='SNV', value='G')         1
# 210           C → Substitution(type_='SNV', value='T')         1
# 211           G → Substitution(type_='SNV', value='C')         1
# 212           T → Substitution(type_='SNV', value='C')         1
# 213           T → Substitution(type_='SNV', value='G')         1
# 214           T → Substitution(type_='SNV', value='C')         1
# 215           A → Substitution(type_='SNV', value='G')         1
# 216           G → Substitution(type_='SNV', value='A')         1
# 217           G → Substitution(type_='SNV', value='T')         1
# 218           C → Substitution(type_='SNV', value='A')         1
# 219           G → Substitution(type_='SNV', value='T')         1
# 220           T → Substitution(type_='SNV', value='C')         1
# 221           A → Substitution(type_='SNV', value='C')         1
# 222           A → Substitution(type_='SNV', value='C')         1
# 223           T → Substitution(type_='SNV', value='C')         1
# 224           A → Substitution(type_='SNV', value='G')         1
# 225           A → Substitution(type_='SNV', value='T')         1
# 226           C → Substitution(type_='SNV', value='T')         9
# 227           C → Substitution(type_='SNV', value='A')        14
# 228           G → Substitution(type_='SNV', value='T')        14
# 229           A → Substitution(type_='SNV', value='C')         2
# 230           G → Substitution(type_='SNV', value='T')        28
# 231           C → Substitution(type_='SNV', value='T')        28
# 232           A → Substitution(type_='SNV', value='T')        28
# 233           G → Substitution(type_='SNV', value='A')         1
# 234           A → Substitution(type_='SNV', value='C')         1
# 235           T → Substitution(type_='SNV', value='G')         1
# 236           C → Substitution(type_='SNV', value='T')         1
# 237           T → Substitution(type_='SNV', value='C')         1
# 238           T → Substitution(type_='SNV', value='C')        16
# 239           A → Substitution(type_='SNV', value='T')        19
# 240           A → Substitution(type_='SNV', value='T')        17
# 241           T → Substitution(type_='SNV', value='A')        17
# 242           G → Substitution(type_='SNV', value='A')       251
# 243           A → Substitution(type_='SNV', value='T')         5
# 244           G → Substitution(type_='SNV', value='A')       250
# 245           G → Substitution(type_='SNV', value='A')        14
# 246           A → Substitution(type_='SNV', value='G')         7
# 247           A → Substitution(type_='SNV', value='G')         1
# 248           G → Substitution(type_='SNV', value='A')         6
# 249           A → Substitution(type_='SNV', value='C')         5
# 250           G → Substitution(type_='SNV', value='C')         5
# 251           C → Substitution(type_='SNV', value='A')         1
# 252           A → Substitution(type_='SNV', value='G')       251
# 253           C → Substitution(type_='SNV', value='T')       251
# 254           C → Substitution(type_='SNV', value='T')       249
# 255           G → Substitution(type_='SNV', value='A')         4
# 256           T → Substitution(type_='SNV', value='C')         5
# 257           C → Substitution(type_='SNV', value='T')         2
# 258           T → Substitution(type_='SNV', value='C')         2
# 259           T → Substitution(type_='SNV', value='C')         2
# 260           T → Substitution(type_='SNV', value='A')         2
# 261           C → Substitution(type_='SNV', value='A')         2
# 262           A → Substitution(type_='SNV', value='G')         2
# 263           T → Substitution(type_='SNV', value='G')         2
# 264           C → Substitution(type_='SNV', value='G')         2
# 265           T → Substitution(type_='SNV', value='G')         2
# 266           T → Substitution(type_='SNV', value='C')         3
# 267           G → Substitution(type_='SNV', value='A')         3
# 268           T → Substitution(type_='SNV', value='C')        12
# 269           T → Substitution(type_='SNV', value='G')        10
# 270           C → Substitution(type_='SNV', value='T')        17
# 271           G → Substitution(type_='SNV', value='C')        15
# 272           G → Substitution(type_='SNV', value='A')        15
# 273           C → Substitution(type_='SNV', value='A')        15
# 274           C → Substitution(type_='SNV', value='A')        15
# 275           A → Substitution(type_='SNV', value='G')         1
# 276           T → Substitution(type_='SNV', value='C')         1
# 277           A → Substitution(type_='SNV', value='G')         1
# 278           G → Substitution(type_='SNV', value='A')        63
# 279         ATT → Substitution(type_='DEL', value='A')        44
# 280           C → Substitution(type_='SNV', value='T')        93
# 281           C → Substitution(type_='SNV', value='T')       210
# 282           C → Substitution(type_='SNV', value='G')       203
# 283           G → Substitution(type_='SNV', value='A')       203
# 284           A → Substitution(type_='SNV', value='C')       235
# 285           A → Substitution(type_='SNV', value='G')        22
# 286           A → Substitution(type_='SNV', value='G')        21
# 287           T → Substitution(type_='SNV', value='G')         7
# 288           A → Substitution(type_='SNV', value='C')         9
# 289           T → Substitution(type_='SNV', value='A')         7
# 290           T → Substitution(type_='SNV', value='C')        19
# 291           C → Substitution(type_='SNV', value='A')         1
# 292           A → Substitution(type_='SNV', value='T')         1
# 293           T → Substitution(type_='SNV', value='C')         3
#
#     Polymorphism Type Variant Frequency (%)    Quality
# 0               Indel                  None    3.22451
# 1               Indel                  None  120.89400
# 2               Indel                  None   22.93610
# 3               Indel                  None  220.67800
# 4               Indel                  None   97.24770
# 5               Indel                  None  220.67800
# 6               Indel                  None  220.90900
# 7               Indel                  None  220.90900
# 8               Indel                  None    3.22451
# 9               Indel                  None    3.22451
# 10              Indel                  None   80.61640
# 11              Indel                  None   95.73020
# 12              Indel                  None  221.96700
# 13              Indel                  None   56.41210
# 14              Indel                  None   69.67040
# 15              Indel                  None   51.30560
# 16              Indel                  None   63.77090
# 17              Indel                  None   60.64720
# 205             Indel                  None   30.41830
# 206             Indel                  None   92.57340
# 207             Indel                  None   55.41460
# 208             Indel                  None   30.41830
# 209             Indel                  None    3.22451
# 210             Indel                  None    3.22451
# 211             Indel                  None    3.22451
# 212             Indel                  None    3.22451
# 213             Indel                  None    3.22451
# 214             Indel                  None    3.22451
# 215             Indel                  None    3.22451
# 216             Indel                  None    3.22451
# 217             Indel                  None    3.22451
# 218             Indel                  None    3.22451
# 219             Indel                  None    3.22451
# 220             Indel                  None    3.22451
# 221             Indel                  None    3.22451
# 222             Indel                  None    3.22451
# 223             Indel                  None    3.22451
# 224             Indel                  None    3.22451
# 225             Indel                  None    3.22451
# 226             Indel                  None   25.90360
# 227             Indel                  None   10.13060
# 228             Indel                  None   10.13060
# 229             Indel                  None   30.41830
# 230             Indel                  None  228.27200
# 231             Indel                  None  228.11800
# 232             Indel                  None  228.27100
# 233             Indel                  None    3.22451
# 234             Indel                  None    3.22451
# 235             Indel                  None    3.22451
# 236             Indel                  None    3.22451
# 237             Indel                  None    3.22451
# 238             Indel                  None    4.93523
# 239             Indel                  None   23.82350
# 240             Indel                  None   43.48340
# 241             Indel                  None   43.48340
# 242             Indel                  None  225.41700
# 243             Indel                  None   12.47920
# 244             Indel                  None  225.41700
# 245             Indel                  None  100.40500
# 246             Indel                  None  138.41600
# 247             Indel                  None    3.22451
# 248             Indel                  None    9.41963
# 249             Indel                  None    8.83533
# 250             Indel                  None    8.83533
# 251             Indel                  None    3.22451
# 252             Indel                  None  225.41700
# 253             Indel                  None  225.41700
# 254             Indel                  None  225.41700
# 255             Indel                  None   79.41490
# 256             Indel                  None   99.41520
# 257             Indel                  None   30.41830
# 258             Indel                  None   30.41830
# 259             Indel                  None   30.41830
# 260             Indel                  None   30.41830
# 261             Indel                  None   30.41830
# 262             Indel                  None   30.41830
# 263             Indel                  None   30.41830
# 264             Indel                  None   30.41830
# 265             Indel                  None   30.41830
# 266             Indel                  None   55.41460
# 267             Indel                  None   55.41460
# 268             Indel                  None  170.15500
# 269             Indel                  None  166.41600
# 270             Indel                  None  225.41700
# 271             Indel                  None  225.41700
# 272             Indel                  None  225.41700
# 273             Indel                  None  225.41700
# 274             Indel                  None  225.41700
# 275             Indel                  None    3.22451
# 276             Indel                  None    3.22451
# 277             Indel                  None    3.22451
# 278             Indel                  None   22.55770
# 279             Indel                  None   17.92890
# 280             Indel                  None   45.16790
# 281             Indel                  None  225.42200
# 282             Indel                  None  225.41700
# 283             Indel                  None  228.36700
# 284             Indel                  None  216.26900
# 285             Indel                  None  225.41700
# 286             Indel                  None  225.41700
# 287             Indel                  None    8.13869
# 288             Indel                  None  157.41600
# 289             Indel                  None  128.41600
# 290             Indel                  None   21.66070
# 291             Indel                  None    3.22451
# 292             Indel                  None    3.22451
# 293             Indel                  None   54.41460

# %%
html_table = variants_df.to_html(index=False)
output_path = "output_files/figures/variants.html"
with open(output_path, "w") as f:
    f.write(html_table)
